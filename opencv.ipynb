# %%
import cv2
import matplotlib.pyplot as plt

# %%
# img = cv2.imread("logo.jpg")
# gray = cv2.imread('logo.jpg',cv2.IMREAD_GRAYSCALE)


# cv2.imshow('image',img)
# cv2.imshow('gray',gray)
# #Wait for any key before image disappears
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)
# ret,frame=cap.read()
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")
ret,frame = cap.read()
# frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
gframe = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
# Displaying the image 
plt.imshow(gframe,cmap='gray')
# plt.imshow(gframe)
# cv2.imshow('frame',frame)

# while True:
#     ret,frame = cap.read()
    
    
# #     img = cv2.imread(frame)
# #     cv2.imshow(img)
# #     gframe=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY )
# #      = cv2.imread(frame)
    
# #     face_casca
    
#     if ret==False:
#         continue
    
#     cv2.imshow("Mihir's Video",frame)
    
#     key_pressed = cv2.waitKey(1) & 0xFF
#     if key_pressed==ord('q'):
#         break
# cap.release()
# cv2.destroyAllWindows()

# %%
# (face_cascade.detectMultiScale())
# eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')

# img = cv2.imread('sachin.jpg')
# gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
import cv2
import matplotlib.pyplot as plt
import numpy as np
face_data=[]
path = './data'
inp=input("Enter name")
# Out:
# Enter nameMihir

# %%
face = cv2.VideoCapture(0)
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")

skip=0

while True:
    ret,frame=face.read()
    if ret==False:
        continue
#     frame=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(frame, 1.3, 5)
    
    faces = sorted(faces,key=lambda f:f[2]*f[3])
    for x,y,w,h in faces[-1:]:
        cv2.rectangle(frame,(x,y),(x+w,x+h),(255,0,0),2)
        os=10
        
        fs=frame[y-os:y+h+os,x-os:x+w+os]
        
        skip+=1;
        if(skip%10==0):
            face_data.append(fs)
            print(len(face_data))
    cv2.imshow('frame',frame)
    cv2.imshow('Face Section',fs)
    key_pressed = cv2.waitKey(1) & 0xFF
    if key_pressed==ord('q'):
        break
        
face_data=np.asarray(face_data)
face_data=face_data.reshape((face_data.shape[0],-1))

np.save(path+inp+'.npy',face_data)

face.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-b4584b1bef36> in <module>
#      20         skip+=1;
#      21         if(skip%10==0):
# ---> 22             face_data.append(fs)
#      23             print(len(face_data))
#      24     cv2.imshow('frame',frame)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
plt.imshow(faces)
